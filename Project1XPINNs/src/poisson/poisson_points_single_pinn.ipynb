# %% [markdown]
# # Poisson Points single domain (only one PINN)

# %%
from region_utils.region import Subdomain, Domain
from region_utils.shapes import ConvexPolygon
import jax.numpy as np
import matplotlib.pyplot as plt

# %%
vertecies = np.array([[0, 0], [0,1], [1, 1], [1, 0]]).reshape(4,-1)
square = ConvexPolygon(
   vertecies,
    [0, 1, 2, 3],
)

subdom = Subdomain([square])
domain = Domain([subdom])

domain.create_interior(400, [0, 0], [1, 1])
domain.create_boundary(40)

# %%
domain.create_interior(400, [0, 0], [1, 1])
domain.create_boundary(40)
domain.plot()

# %%
from utils import data_path

domain.write_to_file(data_path / "poisson_single_pinn_train.json")

# %%
domain.create_testing_data(1000, [0, 0], [1, 1])
domain.write_to_file(data_path / "poisson_single_pinn_test.json", False)
domain.plot(False)
# Out:
# c:\Users\danie\miniconda3\envs\FYS5429\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
