# %% [markdown]
# Emulating the [DFG benchmark 2D-1, Re=20](https://wwwold.mathematik.tu-dortmund.de/~featflow/en/benchmarks/cfdbenchmarking/flow/dfg_benchmark1_re20.html)
# laminar flow (no time dependency) using a single PINN (no domain decomposition)
#
# This notebook contains code for initializing the XPINN, explaining the problem specifications from [DFG benchmark 2D-1](https://wwwold.mathematik.tu-dortmund.de/~featflow/en/benchmarks/cfdbenchmarking/flow/dfg_benchmark1_re20.html), setting up the network architecture, defining the pde residual functions, specifying the boundary conditions and training the network

# %% [markdown]
# #### Initalizing the XPINN
#
# The structure of our train .json data tells XPINN that there is no domain decomposition

# %%
from xpinn import XPINN
import jax.numpy as np
from utils import data_path

data_path = data_path / "NavierStokes"

n_interior = 3000
n_boundary = 500

file_train = data_path / f"single_pinn_train_{n_boundary}_{n_interior}.json"
file_test = data_path / "test.json"
activation = np.tanh
xpinnNoDecomp = XPINN(file_train, activation)

# %%
file_train_no_cylnder = data_path / "NoCylinder"/f"single_pinn_train_{n_boundary}_{n_interior}.json"
xpinnNoDecomp_no_cylinder = XPINN(file_train_no_cylnder, activation)

# %%
file_train = data_path / f"laminar_decomp_train_{n_boundary}_{n_interior}.json"
file_test = data_path / "test.json"
activation = np.tanh
xpinnDecomp = XPINN(file_train, activation)

# %%
file_train_no_cylinder = data_path / "NoCylinder"/f"laminar_decomp_train_{n_boundary}_{n_interior}.json"
xpinnDecomp_no_cylinder = XPINN(file_train_no_cylinder, activation)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.axis("equal"
)
for i, pinn in enumerate(xpinnNoDecomp.PINNs):
    checkout = pinn.interior
    plt.scatter(checkout[:, 0], checkout[:, 1], label=f"index {i}")
    plt.scatter(pinn.boundary[:, 0], pinn.boundary[:, 1], label=f"boundary {i}")

for interface in xpinnNoDecomp.Interfaces:
    a, b = interface.indices
    p = interface.points
    plt.scatter(p[:, 0], p[:, 1], label=f"interface {a}-{b}")

plt.legend()

# %% [markdown]
# # Problem specifications
#
# We attempt to replicate the laminar cylinder-wake navier stokes benchmark from [DFG benchmark 2D-1](https://wwwold.mathematik.tu-dortmund.de/~featflow/en/benchmarks/cfdbenchmarking/flow/dfg_benchmark1_re20.html). The incompressible liquid flows from left to right, hitting the cylinder on its way. In the dortmund article they have used U to denote vector for the fluid flow velocity, in this code however we found it convenient to isolate the x- and y-flow which is denoted respectively as u and v throughout
#
# ### The interior PDE constraints
# In the DFG benchmark 2D-1, the PDE conditions are given by the Navier-Stokes equations:
#
# $$-\nu \nabla^2 \mathbf{u} + (\mathbf{u} \cdot \nabla)\mathbf{u} + \nabla p = \mathbf{0}, \hspace{3mm} \nabla \cdot \mathbf{u} = 0$$
#
# $\nu = 0.001$.
# In our notation, which isolates the x- and y-flow as $u$ and $v$, the PDE expressions for the second-order spatial derivatives can be written as:
#
# $$-\nu (u_{xx} + u_{yy}) + u u_x + v u_y + p_x = 0,$$
#
# $$-\nu (v_{xx} + v_{yy}) + u v_x + v v_y + p_y = 0$$
#
# Our zero divergence from incompressibility:
#
# $$ u_x + v_y = 0$$
#
# Let's denote our PDE in the x and y direction as f and g
#
#
# $$ f = -\nu (u_{xx} + u_{yy}) + u u_x + v u_y + p_x = 0,$$
#
# $$g = -\nu (v_{xx} + v_{yy}) + u v_x + v v_y + p_y = 0$$

# %% [markdown]
# In order to impose the zero divergence we let our network  ($\mathcal{N}_{\theta}$)  predict the stream function $\psi$ and the pressure $p$.
#
# $$\mathcal{N}_{\theta}:\mathbb{R}^2 \to \mathbb{R}^2, \hspace{4mm}(x,y) \to (\psi, p)$$
#
# Then $u$ and $v$ is given by
#
# $$ u = \psi_y,  \hspace{4mm} v = -\psi_x$$

# %% [markdown]
# To see how we could implement these derivatives it's nice to have all of them with respect to $\psi$
#
# $$
# f = - \nu \left(\psi_{yxx} + \psi_{yyy} \right) + \psi_y \psi_{yx} - \psi_{x}\psi_{yy} + p_x
# $$
#
# $$
# g = -\nu \left(-\psi_{xxx} -\psi_{xyy} \right) - \psi_y \psi_{xx} +  \psi_{x} \psi_{xy} + p_y
#
# $$
#
# The second order terms are all in the hessian of $\psi$, so let's have a look at the advection term
#
# $$
# \psi_y \psi_{yx} - \psi_{x}\psi_{yy}
# $$
# $$
# - \psi_y \psi_{xx} +  \psi_{x} \psi_{xy}
# $$
#
# In vector notation this is
#
# $$
#  \begin{bmatrix} -\psi_{yy} & \psi_{yx} \\ \psi_{xy} & -\psi_{xx} \ \end{bmatrix}  \begin{bmatrix} \psi_{x} \\  \psi_{y} \ \end{bmatrix}
# $$
#
# As a reminder the hessian of $\psi$ is
#
# $$
# \begin{bmatrix}
# \psi_{xx} & \psi_{xy} \\
# \psi_{yx} & \psi_{yy}
# \end{bmatrix}
# $$
#
# So the left matrix of our convection term is almost the hessian, we just need to swap the rows
# and negate the diagonal elements. Lets initialize a network such that we have something to take derivatives with respect to

# %%
from typing import Callable
from type_util import Params, Array
from base_network import neural_network
from jax import hessian, jit, vmap, grad, jacobian
import jax.numpy as np

LFunc = Callable[[Params, dict[str, Array]], Array]

model = neural_network(activation)
v_model = vmap(model, (None, 0))

# %% [markdown]
# #### The advection term

# %%
psi = lambda params, xy: model(params, xy)[0]

hess_psi = hessian(psi, argnums=1)
d_psi_dxy = grad(psi, argnums=1)

def advection_term(params: Params, xy: Array) -> Array:
    hess = hess_psi(params, xy)
    processed_hess = np.array([[-hess[1, 1], hess[1, 0]], [hess[1, 0], -hess[0, 0]]])
    return processed_hess @ d_psi_dxy(params, xy)

# %% [markdown]
# #### The Diffusion terms of f an g are
#
# $$
# - \nu \left(\psi_{yxx} + \psi_{yyy} \right)
# $$
#
# $$
#  -\nu \left(-\psi_{xxx} -\psi_{xyy} \right)
# $$

# %% [markdown]
# The jacobian of the hessian includes these terms
# $$
# \begin{bmatrix}
#     \begin{bmatrix}
#         \psi_{xxx} & \psi_{xyx} \\
#         \psi_{yxx} & \psi_{yyx}
#     \end{bmatrix} \\[1em]
#     \begin{bmatrix}
#         \psi_{xxy} & \psi_{xyy} \\
#         \psi_{yxy} & \psi_{yyy}
#     \end{bmatrix}
# \end{bmatrix}
# $$

# %%
jacobi_hess_psi = jacobian(hess_psi, argnums=1)

def diffusion_term(params: Params, xy: Array):
    jachessi = jacobi_hess_psi(params, xy)
    u_diffusion = jachessi[0,1,0] + jachessi[1,1,1] #psi_yxx + psi_yyy
    v_diffusion = jachessi[1,0,1] + jachessi[0,0,0] #psi_xyy + psi_xxx
    return np.array([u_diffusion, -v_diffusion])

# %% [markdown]
# #### Derivatives of p

# %%
p = lambda params, xy: model(params, xy)[1]

d_p = grad(p, argnums=1)

# %% [markdown]
# #### Residual Factory

# %%
def navier_stokes_residual_factory(xpinn, index: int, nu:float, weight: int = 1) -> LFunc:

    def residual(params, xy):
        return np.sum(np.square(advection_term(params, xy) - nu* diffusion_term(params, xy) + d_p(params, xy)))

    v_residual = jit(vmap(residual, (None, 0)))
    xpinn.PINNs[index].v_residual = v_residual
    
    def interior_loss(params: Params, points: dict[str, Array]) -> Array:
        pts = points["interior"]
        return np.mean(v_residual(params, pts)) * weight
    
    
    return interior_loss

# %% [markdown]
# ### Boundary conditions
#
# #### Wall boundary conditions
# There are three 'walls' in our domain, the top and bottom walls and the cylinder. On these walls, we have the so called noslip conditions. That is there is no flow parallel to the boundary exactly on the boundary. The walls are also impermeable, thus the flow velocity is exactly zero on these walls. In the [DFG benchmark 2D-1](https://wwwold.mathematik.tu-dortmund.de/~featflow/en/benchmarks/cfdbenchmarking/flow/dfg_benchmark1_re20.html) this is notated as.
#
#
# ""
#
#
# For the lower and upper walls $\Gamma_1=[0,2.2]\times0$ and $\Gamma_2=[0,2.2]\times0.41$, as well as the boundary $S=\partial B_r(0.2,0.2)$, no-slip boundary conditions are defined:
#
# $$u_{|{\Gamma_1}} = u_{|{\Gamma_3}} = u_{|_S} = \boldsymbol{0}$$
#
# ""
#
# Using our notation we get
#
# $$u_{|{\Gamma_1}} = u_{|{\Gamma_3}} = u_{|_S} = 0$$
# $$v_{|{\Gamma_1}} = v_{|{\Gamma_3}} = v_{|_S} = 0$$
#
#
# #### Left boundary
#
# On the left bondary we have a polynomial inflow
#
# $$u = \frac{4U y(0.41-y)}{0.41^2}$$
# $$v = 0$$
#
# $U = 0.3$
#
# #### Right boundary
#
# On the right boundary we have the do-nothing boundary condition. [DFG benchmark 2D-1](https://wwwold.mathematik.tu-dortmund.de/~featflow/en/benchmarks/cfdbenchmarking/flow/dfg_benchmark1_re20.html) denotes this as
#
# $$\nu\partial_{\eta} u - p\eta = 0$$
#
# where $\eta$ denotes the unit normal vector to the boundary, which is just $(1,0)$. In our notation this is rather simple
#
# $$
# \nu u_x  - p = 0
# $$
#
# $$
# \nu u_y  = 0
# $$

# %% [markdown]
# #### Inflow

# %%
inflow_func_1d = lambda x: 4*0.3*x*(0.41-x)/0.41**2
x = np.linspace(0, 0.41, 100)
plt.plot(x, inflow_func_1d(x))

# %%
U = 0.3

inflow_func = lambda xy: np.array((4 * U * xy[1] * (0.41 - xy[1])/(0.41**2), 0.0))

# %% [markdown]
# #### Boundary loss factory

# %%
from typing import Tuple

def uv(params: Params, xy: Array) -> Array:
    d_psi = d_psi_dxy(params, xy)
    return np.array([d_psi[1], -d_psi[0]])

def boundary_loss_factory2(inflow_func: Callable[[Array], Array], nu:float, weights:Tuple[int, int, int, int]= (1,1,1,1)) -> LFunc:
    
    def left_boundary_loss(params, xy):
        return np.sum(np.square(uv(params, xy) - inflow_func(xy))) #(u - inflow)**2 + v**2
    
    def wall_boundary_loss(params, xy):
        return np.sum(np.square(uv(params, xy))) #return u**2 + v**2
        
    def right_boundary_loss(params, xy):
        return np.sum(np.square(nu*hess_psi(params, xy)[:,1] - np.array((p(params,xy), 0))))# (nu*u_x-p)**2 + (nu*u_y)**2
    
    v_left_boundary_loss = vmap(left_boundary_loss, (None, 0))
    v_wall_boundary_loss = vmap(wall_boundary_loss, (None, 0))
    v_right_boundary_loss = vmap(right_boundary_loss, (None, 0))
    
    def boundary_loss(params: Params, points: dict[str, Array]) -> Array:

        left_pts = points['left boundary']
        right_pts = points['right boundary']
        wall_pts = points['wall boundary']
        cylinder_pts = points['cylinder boundary']
       
        left = v_left_boundary_loss(params, left_pts)
        right = v_right_boundary_loss(params, right_pts)
        wall = v_wall_boundary_loss(params, wall_pts)
        cylinder = v_wall_boundary_loss(params, cylinder_pts)
    
        #all = np.sum(np.mean(np.array((left, wall, right)), axis=0))
        all = np.sum(np.array((np.mean(left)*weights[0], np.mean(wall)*weights[1], np.mean(right)*weights[2], np.mean(cylinder)*weights[3])))
        return all
    
    return boundary_loss

# %%
def cylinder_boundary_loss_factory(weight: int = 1) -> LFunc:
    
    def wall_boundary_loss(params, xy):
        return np.sum(np.square(uv(params, xy))) #return u**2 + v**2
    
    v_wall_boundary_loss = vmap(wall_boundary_loss, (None, 0))
    
    def boundary_loss(params: Params, points: dict[str, Array]) -> Array:

        cylinder_pts = points['cylinder boundary']
        
        cylinder = v_wall_boundary_loss(params, cylinder_pts)
    
        return np.mean(cylinder)*weight
    
    return boundary_loss

# %%
def boundary_loss_factory_no_cylinder(inflow_func: Callable[[Array], Array], nu:float, weights:Tuple[int, int, int]= (1,1,1) ) -> LFunc:
    
    def left_boundary_loss(params, xy):
        return np.sum(np.square(uv(params, xy) - inflow_func(xy))) #(u - inflow)**2 + v**2
        
    def right_boundary_loss(params, xy):
        return np.sum(np.square(nu*hess_psi(params, xy)[:,1] - np.array((p(params,xy), 0)))) # (nu*u_x-p)**2 + (nu*u_y)**2
        
    def wall_boundary_loss(params, xy):
        return np.sum(np.square(uv(params, xy))) #return u**2 + v**2
    
    v_wall_boundary_loss = vmap(wall_boundary_loss, (None, 0))
    v_left_boundary_loss = vmap(left_boundary_loss, (None, 0))
    v_right_boundary_loss = vmap(right_boundary_loss, (None, 0))
    
    def boundary_loss(params: Params, points: dict[str, Array]) -> Array:

        left_pts = points['left boundary']
        right_pts = points['right boundary']
        wall_pts = points['wall boundary']
    
        left = v_left_boundary_loss(params, left_pts)
        right = v_right_boundary_loss(params, right_pts)
        wall = v_wall_boundary_loss(params, wall_pts)
    
        
        all =  np.sum(np.array((np.mean(left)*weights[0], np.mean(wall)*weights[1], np.mean(right)*weights[2])))
        return all
    
    return boundary_loss

# %%
def interface_loss_factory(xpinn, i: int, j: int) -> LFunc:
    a, b = sorted([i, j])
    pi = xpinn.PINNs[i]

    def interface_loss(params: Params, args: dict[str, Array]) -> Array:
        inter_points = args[f"interface {a}{b}"]
        res_j = args[f"interface res {j}"]
        res_ij = np.mean((pi.v_residual(params, inter_points) - res_j) ** 2)
        # res_ij = 0

        val_j = args[f"interface val {j}"]
        avg_ij = np.mean(((v_model(params, inter_points) - val_j) / 2) ** 2)
        # avg_ij = 0

        return 80 * (res_ij + avg_ij)

    return interface_loss

# %%
p0 = xpinnDecomp_no_cylinder.PINNs[0]
p0.boundary_loss = boundary_loss_factory_no_cylinder(inflow_func, 0.001, (30,5,5))
p0.interior_loss = navier_stokes_residual_factory(xpinn=xpinnDecomp_no_cylinder, index=0, nu=0.001, weight=20)


p1 = xpinnDecomp_no_cylinder.PINNs[1]
p1.interior_loss = navier_stokes_residual_factory(xpinn=xpinnDecomp_no_cylinder,index=1, nu=0.001, weight=20)

p0.interface_loss = interface_loss_factory(xpinnDecomp_no_cylinder,0, 1)
p1.interface_loss = interface_loss_factory(xpinnDecomp_no_cylinder, 1, 0)

p0.create_loss()
p1.create_loss()
# Out:
# <PjitFunction of <function PINN.create_loss.<locals>.loss at 0x000001F34F54CAE0>>

# %%
p0 = xpinnDecomp.PINNs[0]
p0.boundary_loss = boundary_loss_factory_no_cylinder(inflow_func, nu=0.001, weights=(100,25,25))
p0.interior_loss = navier_stokes_residual_factory(xpinnDecomp, index=0, nu=0.001, weight=200)

p1 = xpinnDecomp.PINNs[1]
p1.boundary_loss = cylinder_boundary_loss_factory(weight=25)
p1.interior_loss = navier_stokes_residual_factory(xpinnDecomp, index=1, nu=0.001, weight=200)

p0.interface_loss = interface_loss_factory(xpinnDecomp, 0, 1)
p1.interface_loss = interface_loss_factory(xpinnDecomp, 1, 0)


p0.create_loss()
p1.create_loss()
# Out:
# <PjitFunction of <function PINN.create_loss.<locals>.loss at 0x000001F330FCCEA0>>

# %%
p0 = xpinnNoDecomp_no_cylinder.PINNs[0]
p0.boundary_loss = boundary_loss_factory_no_cylinder(inflow_func, nu=0.001, weights=(100,25,25))
p0.interior_loss = navier_stokes_residual_factory(xpinnNoDecomp_no_cylinder, 0, nu=0.001, weight=200)
p0.create_loss()
# Out:
# <PjitFunction of <function PINN.create_loss.<locals>.loss at 0x000001F34F5DE480>>

# %%
p0 = xpinnNoDecomp.PINNs[0]
p0.boundary_loss = boundary_loss_factory2(inflow_func, nu=0.001, weights=(100,25,25,25))
p0.interior_loss = navier_stokes_residual_factory(xpinnNoDecomp, 0, nu=0.001, weight=200)
p0.create_loss()
# Out:
# <PjitFunction of <function PINN.create_loss.<locals>.loss at 0x000001F34F5DF1A0>>

# %%
import optax

shape = [2] + 9*[20] + [2]

exponential_decay = optax.exponential_decay(
    init_value=0.001,
    transition_steps=10000,
    transition_begin=15000,
    decay_rate=0.1,
    end_value=0.0000001
)

optimizer = optax.adam(learning_rate=exponential_decay)

xpinnNoDecomp_no_cylinder.PINNs[0].init_params(shape, optimizer)
# Out:
# C:\Users\danie\OneDrive - Universitetet i Oslo\Documents\vår2024\FYS5429\FYS5429\Project1XPINNs\src\base_network.py:24: UserWarning: Explicitly requested dtype <class 'jax.numpy.float64'>  is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return scale * random.normal(
# C:\Users\danie\OneDrive - Universitetet i Oslo\Documents\vår2024\FYS5429\FYS5429\Project1XPINNs\src\base_network.py:26: UserWarning: Explicitly requested dtype <class 'jax.numpy.float64'>  is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   ), scale * random.normal(b_key, (n,), dtype=np.float64)

# %%
n_iter = 20000
losses = xpinnNoDecomp_no_cylinder.run_iters(n_iter)
# Out:
# 0.00% iter = 0 of 20000: Total loss = 12.421082496643066
# 10.00% iter = 2000 of 20000: Total loss = 0.4226141571998596
# 20.00% iter = 4000 of 20000: Total loss = 0.2822631895542145
# 30.00% iter = 6000 of 20000: Total loss = 0.24387510120868683
# 40.00% iter = 8000 of 20000: Total loss = 0.21984915435314178
# 50.00% iter = 10000 of 20000: Total loss = 0.2049526572227478
# 60.00% iter = 12000 of 20000: Total loss = 0.20335760712623596
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 n_iter = 20000
# ----> 2 losses = xpinn.run_iters(n_iter)
#
# File ~\OneDrive - Universitetet i Oslo\Documents\vår2024\FYS5429\FYS5429\Project1XPINNs\src\xpinn.py:171, in XPINN.run_iters(self, num_epoch)
#     168 self.set_loss()
#     170 for epoch in range(num_epoch):
# --> 171     self.optimize_iter(epoch)
#     173     iter_loss = sum(self.losses[:, epoch])
#     174     if epoch % print_num == 0:
#
# File ~\OneDrive - Universitetet i Oslo\Documents\vår2024\FYS5429\FYS5429\Project1XPINNs\src\xpinn.py:150, in XPINN.optimize_iter(self, epoch)
#     146 iter_loss = pinn.loss(pinn.params, args)
#     148 self.losses[i, epoch] = iter_loss
# --> 150 params, optstate = pinn.update_iteration(
#     151     pinn.grad_loss,
#     152     pinn.params,
#     153     args,
#     154     pinn.optimizer,
#     155     pinn.optstate,
#     156 )
#     157 # Typehinting
#     158 params: Params
#
# File <string>:1, in <lambda>(_cls, count, mu, nu)
#
# KeyboardInterrupt:

# %%
shapes = [[2] + [20] * 9 + [1]] * 2
xpinnDecomp_no_cylinder.initialize_params(shapes, optimizer)
xpinnDecomp_no_cylinder.run_iters(n_iter)

# %%
from utils import model_path



no_cylinder_path_decomp = model_path / "NavierStokes"/ "Decomp"/ "laminar" / "NoCylinder"/f"ADAM_{n_iter}_iter_9layer"
xpinnDecomp_no_cylinder.save_model(no_cylinder_path_decomp)

no_cylinder_path_no_decomp = model_path / "NavierStokes"/ "NoDecomp"/ "laminar" / "NoCylinder"/f"ADAM_{n_iter}_iter_9layer"
xpinnNoDecomp_no_cylinder.save_model(no_cylinder_path_no_decomp)

# %%
pretrained_path = model_path / "NavierStokes"/ "NoDecomp"/ "laminar" /f"Pretrained_ADAM_{n_iter}_iter_9layer"
for i in range(3):
    optimizer = optax.adam(learning_rate=exponential_decay)
    xpinnNoDecomp.load_model(no_cylinder_path_no_decomp)
    xpinnNoDecomp.set_optimizer(optimizer)
    losses = xpinnNoDecomp.run_iters(n_iter)
    path = pretrained_path / f"model{i}"
    xpinnNoDecomp.save_model(path)

# %%
pretrained_path = model_path / "NavierStokes"/ "Decomp"/ "laminar" /f"Pretrained_ADAM_{n_iter}_iter_9layer"
for i in range(3):
    optimizer = optax.adam(learning_rate=exponential_decay)
    xpinnDecomp.load_model(no_cylinder_path_decomp)
    xpinnDecomp.set_optimizer(optimizer)
    losses = xpinnDecomp.run_iters(n_iter)
    path = pretrained_path / f"model{i}"
    xpinnDecomp.save_model(path)

# %%
no_pretrained_path = model_path / "NavierStokes"/ "NoDecomp"/ "laminar" /f"ADAM_{n_iter}_iter_9layer"
for i in range(3):
    optimizer = optax.adam(learning_rate=exponential_decay)
    xpinnNoDecomp.initialize_params(shapes, optimizer)
    losses = xpinnNoDecomp.run_iters(n_iter)
    path = pretrained_path / f"model{i}"
    xpinnNoDecomp_no_cylinder.save_model(path)

# %%
no_cylinder_path_decomp = model_path / "NavierStokes"/ "Decomp"/ "laminar" / "NoCylinder"/f"ADAM_{n_iter}_iter_9layer"
for i in range(3):
    optimizer = optax.adam(learning_rate=exponential_decay)
    xpinnDecomp.initialize_params(shapes, optimizer)
    losses = xpinnDecomp.run_iters(n_iter)
    path = pretrained_path / f"model{i}"
    xpinnDecomp.save_model(path)

# %%
a[

# %% [markdown]
# There is a lot more boundary loss than resiudal loss. Needs investigation

# %%
#This is currently some what fucked

def left_boundary_loss(params, xy):
    return np.sum(np.square(d_psi_dxy(params, xy) - inflow_func(xy))) #(u - inflow)**2 + v**2

def wall_boundary_loss(params, xy):
    return np.sum(np.square(d_psi_dxy(params, xy))) #return u**2 + v**2
    
def right_boundary_loss(params, xy):
    return 0.001*np.square(np.sum(hess_psi(params, xy)[:,1])) # nu*u_x**2 + nu*u_y**2

v_left_boundary_loss = vmap(left_boundary_loss, (None, 0))
v_wall_boundary_loss = vmap(wall_boundary_loss, (None, 0))
v_right_boundary_loss = vmap(right_boundary_loss, (None, 0))

def boundary_loss(params: Params, points: dict[str, Array]) -> Array:

    left_pts = points['left boundary']
    right_pts = points['right boundary']
    wall_pts = points['wall boundary']
    cylinder_pts = points['cylinder boundary']
    
    left = v_left_boundary_loss(params, left_pts)
    right = v_right_boundary_loss(params, right_pts)
    wall = v_wall_boundary_loss(params, wall_pts)
    cylinder = v_wall_boundary_loss(params, cylinder_pts)

    #all = np.sum(np.mean(np.array((left, wall, right)), axis=0))
    all = np.sum(np.array((np.mean(left), np.mean(wall), np.mean(right), np.mean(cylinder))))
    print(np.mean(left), np.mean(wall), np.mean(right), np.mean(cylinder))
    return all*200

# %%
a_losses = losses
t_0 = 0
t_end = min(20000, n_iter)
t = np.arange(t_0, t_end)

plt.plot(t, a_losses[0, t_0:t_end])
plt.xlabel("epoch")
plt.ylabel("loss")
plt.yscale("log")
plt.title(f"Loss over {n_iter} epochs")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 a_losses = losses
#       2 t_0 = 0
#       3 t_end = min(20000, n_iter)
#
# NameError: name 'losses' is not defined

# %% [markdown]
# #### Load trained model and plot results

# %%
#load_model_iter = 5000
#our_model_path = model_path / "NavierStokes"/ "single_pinn"/ "laminar" / f"ADAM_5000_JUNMAIO_x64_2000"
#xpinn.load_model(our_model_path)

# %%
def uv(params, xy):
    v_negated, u = d_psi_dxy(params, xy)
    return np.array([u, -v_negated])

uv = jit(vmap(uv, (None, 0)))
p = jit(vmap(p, (None, 0)))
j_model = jit(v_model)

# %%
def pinn_predict(params, args: dict[str, Array]):
    b = args["boundary"]
    i = args["interior"]
    if b.size == 0:
        points = i
    else:
        points = np.vstack([b, i])

    net_output = j_model(params, points)
    pressure = net_output[:, 1]
    #pressure = p(params, points)
    streamfunction = net_output[:, 0]
    flow = uv(params, points)
    flow_magnitude = np.sqrt(np.sum(flow**2, axis=1))

    return points, flow, flow_magnitude, pressure, streamfunction

# %%
import json
from pathlib import Path

def predict(input_file: str | Path = None):
    if input_file:
        main_args = {}
        with open(input_file) as infile:
            data = json.load(infile)

        for i, item in enumerate(data["XPINNs"]):
            interior = np.asarray(item["Internal points"])
            boundary = np.asarray(item["Boundary points"])

            main_args[i] = {"boundary": boundary, "interior": interior}

    else:
        main_args = xpinn.main_args

    total_streamfunction = []
    total_points = []
    total_flow = []
    total_p = []
    total_flow_magnitude = []


    for i, pinn in enumerate(xpinn.PINNs):
        params = pinn.params
        points, flow, flow_magnitude, p, streamfunction = pinn_predict(params, main_args[i])
        
        total_flow_magnitude.append(flow_magnitude)
        total_streamfunction.append(streamfunction)
        total_points.append(points)
        total_flow.append(flow)
        total_p.append(p)

    return total_points, total_flow, total_flow_magnitude, total_p, total_streamfunction

# %%
points, flow, flow_magitude, pressure, streamfunction = predict(file_test)

# %%
tot_flow_magnitude = np.concatenate(flow_magitude)
min_, max_ = tot_flow_magnitude.min(), tot_flow_magnitude.max()

for point, pred in zip(points, flow_magitude):
    plt.scatter(point[:,0], point[:,1], c = pred, cmap="turbo", label="Flow Magnitude", s=1)
plt.title("flow magnitude")
plt.clim(min_, max_)
plt.axis("equal")
plt.colorbar()

# %%
tot_pressure  =  np.concatenate(pressure)
min_, max_ = tot_pressure.min(), tot_pressure.max()

for point, pred in zip(points, pressure):
    plt.scatter(point[:,0], point[:,1], c = pred, cmap="turbo", label="pressure", s=1 )
plt.title("pressure")
plt.clim(min_, max_)
plt.axis("equal")
plt.colorbar()

# %%
tot_streamfunction = np.concatenate(streamfunction)
in_, max_ = tot_streamfunction.min(), tot_streamfunction.max()


for point, pred in zip(points, streamfunction):
    plt.scatter(point[:,0], point[:,1], c = pred, cmap="turbo", label="streamfunction", s=1)
plt.title("Streamfunction")
#plt.clim(min_, max_)
plt.axis("equal")
plt.colorbar()

# %% [markdown]
# Alt boundary loss

# %%
def uv(params: Params, xy: Array) -> Array:
    d_psi = d_psi_dxy(params, xy)
    return np.array([d_psi[1], -d_psi[0]])

def boundary_loss_factory(inflow_func: Callable[[Array], Array], nu:float, weight: int = 1) -> LFunc:
    
    def left_boundary_loss(params, xy):
        return np.sum(np.square(uv(params, xy) - inflow_func(xy))) #(u - inflow)**2 + v**2
    
    def wall_boundary_loss(params, xy):
        return np.sum(np.square(uv(params, xy))) #return u**2 + v**2
        
    def right_boundary_loss(params, xy):
        return np.sum(np.square(nu*hess_psi(params, xy)[:,1] - np.array((p(params,xy), 0)))) # (nu*u_x-p)**2 + (nu*u_y)**2
    
    v_left_boundary_loss = vmap(left_boundary_loss, (None, 0))
    v_wall_boundary_loss = vmap(wall_boundary_loss, (None, 0))
    v_right_boundary_loss = vmap(right_boundary_loss, (None, 0))
    
    def boundary_loss(params: Params, points: dict[str, Array]) -> Array:

        left_pts = points['left boundary']
        right_pts = points['right boundary']
        wall_pts = points['wall boundary']
        cylinder_pts = points['cylinder boundary']
       
        left = v_left_boundary_loss(params, left_pts)
        right = v_right_boundary_loss(params, right_pts)
        wall = v_wall_boundary_loss(params, wall_pts)
        cylinder = v_wall_boundary_loss(params, cylinder_pts)
    
        all = np.concatenate((left, wall, right, cylinder))
        return np.mean(all)*weight
    
    return boundary_loss
