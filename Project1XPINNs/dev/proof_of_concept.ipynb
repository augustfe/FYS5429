# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Separating points into sub-domains

# %%
regions = [[] for i in range(3)]

# %%
x_vals = np.random.uniform(-1, 1, (2000, 1))
t_vals = np.random.uniform(0, 1, (2000, 1))

# %%
X = np.hstack([x_vals, t_vals])

# %%
X
# Out:
# array([[ 0.1632072 ,  0.93270361],
#        [-0.86597472,  0.50959148],
#        [ 0.27072167,  0.62510011],
#        ...,
#        [-0.16931093,  0.59542122],
#        [ 0.00448092,  0.72598334],
#        [ 0.62323484,  0.04673413]])

# %%
plt.scatter(X[:, 0], X[:, 1])

# %%
regions = [[] for i in range(3)]

for x, t in X:
    if -0.2 >= x - 0.5 * t:
        regions[0].append([x, t])
    elif x - 0.5 * t >= 0.2:
        regions[1].append([x, t])
    else:
        regions[2].append([x, t])

for i, sub_list in enumerate(regions):
    regions[i] = np.array(regions[i])

for i, sub_list in enumerate(regions):
    plt.scatter(sub_list[:, 0], sub_list[:, 1], s=2.5, label=f"Region {i+1}")
plt.legend()

# %% [markdown]
# ### Adding boundary and interface points

# %%
BOUNDARY = 200
NUM_BOUNDARIES = 5
POINTS_PER_BOUND = BOUNDARY / NUM_BOUNDARIES

def bound_1():
